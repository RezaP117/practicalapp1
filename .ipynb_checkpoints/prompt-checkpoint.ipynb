# %% [markdown]
# ### Will a Customer Accept the Coupon?
#
# **Context**
#
# Imagine driving through town and a coupon is delivered to your cell phone for a restaraunt near where you are driving. Would you accept that coupon and take a short detour to the restaraunt? Would you accept the coupon but use it on a sunbsequent trip? Would you ignore the coupon entirely? What if the coupon was for a bar instead of a restaraunt? What about a coffee house? Would you accept a bar coupon with a minor passenger in the car? What about if it was just you and your partner in the car? Would weather impact the rate of acceptance? What about the time of day?
#
# Obviously, proximity to the business is a factor on whether the coupon is delivered to the driver or not, but what are the factors that determine whether a driver accepts the coupon once it is delivered to them? How would you determine whether a driver is likely to accept a coupon?
#
# **Overview**
#
# The goal of this project is to use what you know about visualizations and probability distributions to distinguish between customers who accepted a driving coupon versus those that did not.
#
# **Data**
#
# This data comes to us from the UCI Machine Learning repository and was collected via a survey on Amazon Mechanical Turk. The survey describes different driving scenarios including the destination, current time, weather, passenger, etc., and then ask the person whether he will accept the coupon if he is the driver. Answers that the user will drive there ‘right away’ or ‘later before the coupon expires’ are labeled as ‘Y = 1’ and answers ‘no, I do not want the coupon’ are labeled as ‘Y = 0’.  There are five different types of coupons -- less expensive restaurants (under \\$20), coffee houses, carry out & take away, bar, and more expensive restaurants (\\$20 - \\$50).

# %% [markdown]
# **Deliverables**
#
# Your final product should be a brief report that highlights the differences between customers who did and did not accept the coupons.  To explore the data you will utilize your knowledge of plotting, statistical summaries, and visualization using Python. You will publish your findings in a public facing github repository as your first portfolio piece.

# %% [markdown]
# ### Data Description
# Keep in mind that these values mentioned below are average values.
#
# The attributes of this data set include:
# 1. User attributes
#     -  Gender: male, female
#     -  Age: below 21, 21 to 25, 26 to 30, etc.
#     -  Marital Status: single, married partner, unmarried partner, or widowed
#     -  Number of children: 0, 1, or more than 1
#     -  Education: high school, bachelors degree, associates degree, or graduate degree
#     -  Occupation: architecture & engineering, business & financial, etc.
#     -  Annual income: less than \\$12500, \\$12500 - \\$24999, \\$25000 - \\$37499, etc.
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she buys takeaway food: 0, less than 1, 1 to 3, 4 to 8 or greater
#     than 8
#     -  Number of times that he/she goes to a coffee house: 0, less than 1, 1 to 3, 4 to 8 or
#     greater than 8
#     -  Number of times that he/she eats at a restaurant with average expense less than \\$20 per
#     person: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#     -  Number of times that he/she goes to a bar: 0, less than 1, 1 to 3, 4 to 8 or greater than 8
#
#
# 2. Contextual attributes
#     - Driving destination: home, work, or no urgent destination
#     - Location of user, coupon and destination: we provide a map to show the geographical
#     location of the user, destination, and the venue, and we mark the distance between each
#     two places with time of driving. The user can see whether the venue is in the same
#     direction as the destination.
#     - Weather: sunny, rainy, or snowy
#     - Temperature: 30F, 55F, or 80F
#     - Time: 10AM, 2PM, or 6PM
#     - Passenger: alone, partner, kid(s), or friend(s)
#
#
# 3. Coupon attributes
#     - time before it expires: 2 hours or one day

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %% [markdown]
# ### Problems
#
# Use the prompts below to get started with your data analysis.
#
# 1. Read in the `coupons.csv` file.

# %%
data = pd.read_csv('data/coupons.csv')

# %%
data.head(20)
# Out:
#         destination  passanger weather  temperature  time  \
# 0   No Urgent Place      Alone   Sunny           55   2PM
# 1   No Urgent Place  Friend(s)   Sunny           80  10AM
# 2   No Urgent Place  Friend(s)   Sunny           80  10AM
# 3   No Urgent Place  Friend(s)   Sunny           80   2PM
# 4   No Urgent Place  Friend(s)   Sunny           80   2PM
# 5   No Urgent Place  Friend(s)   Sunny           80   6PM
# 6   No Urgent Place  Friend(s)   Sunny           55   2PM
# 7   No Urgent Place     Kid(s)   Sunny           80  10AM
# 8   No Urgent Place     Kid(s)   Sunny           80  10AM
# 9   No Urgent Place     Kid(s)   Sunny           80  10AM
# 10  No Urgent Place     Kid(s)   Sunny           80   2PM
# 11  No Urgent Place     Kid(s)   Sunny           55   2PM
# 12  No Urgent Place     Kid(s)   Sunny           55   6PM
# 13             Home      Alone   Sunny           55   6PM
# 14             Home      Alone   Sunny           55   6PM
# ...

# %% [markdown]
# 2. Investigate the dataset for missing or problematic data.

# %%
nan_counts = data.isna().sum()
nan_counts
# Out:
# destination                 0
# passanger                   0
# weather                     0
# temperature                 0
# time                        0
# coupon                      0
# expiration                  0
# gender                      0
# age                         0
# maritalStatus               0
# has_children                0
# education                   0
# occupation                  0
# income                      0
# car                     12576
# Bar                       107
# CoffeeHouse               217
# CarryAway                 151
# RestaurantLessThan20      130
# Restaurant20To50          189
# toCoupon_GEQ5min            0
# toCoupon_GEQ15min           0
# toCoupon_GEQ25min           0
# direction_same              0
# direction_opp               0
# Y                           0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
# ...

# %%
data.describe()
# Out:
#         temperature  has_children  toCoupon_GEQ5min  toCoupon_GEQ15min  \
# count  12684.000000  12684.000000           12684.0       12684.000000
# mean      63.301798      0.414144               1.0           0.561495
# std       19.154486      0.492593               0.0           0.496224
# min       30.000000      0.000000               1.0           0.000000
# 25%       55.000000      0.000000               1.0           0.000000
# 50%       80.000000      0.000000               1.0           1.000000
# 75%       80.000000      1.000000               1.0           1.000000
# max       80.000000      1.000000               1.0           1.000000
#
#        toCoupon_GEQ25min  direction_same  direction_opp             Y
# count       12684.000000    12684.000000   12684.000000  12684.000000
# mean            0.119126        0.214759       0.785241      0.568433
# std             0.323950        0.410671       0.410671      0.495314
# ...

# %% [markdown]
# 3. Decide what to do about your missing data -- drop, replace, other...

# %%
data_no_nulls = data.dropna()
data_no_nulls
# Out:
#           destination  passanger weather  temperature  time  \
# 1237  No Urgent Place      Alone   Sunny           55   2PM
# 1238  No Urgent Place  Friend(s)   Sunny           80  10AM
# 1239  No Urgent Place  Friend(s)   Sunny           80  10AM
# 1240  No Urgent Place  Friend(s)   Sunny           80  10AM
# 1241  No Urgent Place  Friend(s)   Sunny           80   2PM
# ...               ...        ...     ...          ...   ...
# 8293             Work      Alone   Rainy           55   7AM
# 8294             Work      Alone   Rainy           55   7AM
# 8295             Work      Alone   Snowy           30   7AM
# 8296             Work      Alone   Snowy           30   7AM
# 8297             Work      Alone   Sunny           80   7AM
#
#                      coupon expiration gender age maritalStatus  ...  \
# 1237        Restaurant(<20)         1d   Male  26        Single  ...
# 1238           Coffee House         2h   Male  26        Single  ...
# ...

# %% [markdown]
# 4. What proportion of the total observations chose to accept the coupon?

# %%
accepted = data.query("Y == 1")
accepted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7210 entries, 0 to 12680
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           7210 non-null   object
#  1   passanger             7210 non-null   object
#  2   weather               7210 non-null   object
#  3   temperature           7210 non-null   int64
#  4   time                  7210 non-null   object
#  5   coupon                7210 non-null   object
#  6   expiration            7210 non-null   object
#  7   gender                7210 non-null   object
#  8   age                   7210 non-null   object
#  9   maritalStatus         7210 non-null   object
#  10  has_children          7210 non-null   int64
#  11  education             7210 non-null   object
#  12  occupation            7210 non-null   object
#  13  income                7210 non-null   object
#  14  car                   62 non-null     object
# ...

# %%
declined  = data.query("Y == 0")
declined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5474 entries, 1 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           5474 non-null   object
#  1   passanger             5474 non-null   object
#  2   weather               5474 non-null   object
#  3   temperature           5474 non-null   int64
#  4   time                  5474 non-null   object
#  5   coupon                5474 non-null   object
#  6   expiration            5474 non-null   object
#  7   gender                5474 non-null   object
#  8   age                   5474 non-null   object
#  9   maritalStatus         5474 non-null   object
#  10  has_children          5474 non-null   int64
#  11  education             5474 non-null   object
#  12  occupation            5474 non-null   object
#  13  income                5474 non-null   object
#  14  car                   46 non-null     object
# ...

# %% [markdown]
# # Answer to question 4

# %%
ratio_accepted = 7210 / (7210 + 5474)
ratio_accepted
# 56% of people from the total observations accepted the coupon
# Out:
# 0.5684326710816777

# %% [markdown]
# 5. Use a bar plot to visualize the `coupon` column.

# %%
countplot = sns.countplot(data=data, x='coupon')
countplot.set_xticklabels(countplot.get_xticklabels(), rotation=45, ha='right')
# Out:
# [Text(0, 0, 'Restaurant(<20)'),
#  Text(1, 0, 'Coffee House'),
#  Text(2, 0, 'Carry out & Take away'),
#  Text(3, 0, 'Bar'),
#  Text(4, 0, 'Restaurant(20-50)')]

# %% [markdown]
# 6. Use a histogram to visualize the temperature column.

# %%
sns.displot(data = data, x = "temperature")

# %% [markdown]
# **Investigating the Bar Coupons**
#
# Now, we will lead you through an exploration of just the bar related coupons.
#
# 1. Create a new `DataFrame` that contains just the bar coupons.

# %%
bar_data = data.query("coupon == 'Bar'")
bar_data
# Out:
#            destination  passanger weather  temperature  time coupon  \
# 9      No Urgent Place     Kid(s)   Sunny           80  10AM    Bar
# 13                Home      Alone   Sunny           55   6PM    Bar
# 17                Work      Alone   Sunny           55   7AM    Bar
# 24     No Urgent Place  Friend(s)   Sunny           80  10AM    Bar
# 35                Home      Alone   Sunny           55   6PM    Bar
# ...                ...        ...     ...          ...   ...    ...
# 12663  No Urgent Place  Friend(s)   Sunny           80  10PM    Bar
# 12664  No Urgent Place  Friend(s)   Sunny           55  10PM    Bar
# 12667  No Urgent Place      Alone   Rainy           55  10AM    Bar
# 12670  No Urgent Place    Partner   Rainy           55   6PM    Bar
# 12682             Work      Alone   Snowy           30   7AM    Bar
#
#       expiration  gender age      maritalStatus  ...  CoffeeHouse CarryAway  \
# ...

# %% [markdown]
# 2. What proportion of bar coupons were accepted?

# %% [markdown]
# # Answer to question 2

# %%
# Count the occurrences of each value in the column
value_counts = bar_data["Y"].value_counts()

# Calculate the ratio
ratio = value_counts[1] / len(bar_data["Y"])
ratio
# the ratio for the number of bar coupons accepted is 41%
# Out:
# 0.41001487357461575

# %%
bar_accepted = bar_data.query("Y == 1")
bar_declined = bar_data.query("Y == 0")

# %%
bar_accepted.info()
bar_declined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 827 entries, 13 to 12652
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           827 non-null    object
#  1   passanger             827 non-null    object
#  2   weather               827 non-null    object
#  3   temperature           827 non-null    int64
#  4   time                  827 non-null    object
#  5   coupon                827 non-null    object
#  6   expiration            827 non-null    object
#  7   gender                827 non-null    object
#  8   age                   827 non-null    object
#  9   maritalStatus         827 non-null    object
#  10  has_children          827 non-null    int64
#  11  education             827 non-null    object
#  12  occupation            827 non-null    object
#  13  income                827 non-null    object
#  14  car                   3 non-null      object
# ...

# %%
total_bar = 1190 + 827
ratio_bar_accepted = (827 / total_bar)
ratio_bar_accepted
# double checking for accepted bar coupon percentage
# Out:
# 0.41001487357461575

# %% [markdown]
# 3. Compare the acceptance rate between those who went to a bar 3 or fewer times a month to those who went more.

# %%
#bar_options = ['never', 'less1', '1~3', 'gt8', nan, '4~8']
bar_3_or_fewer = bar_data.query("Bar not in ['gt8', '4~8']")
bar_3_or_more = bar_data.query("Bar in ['gt8', '4~8']")

# %%
bar_3_or_more
# Out:
#            destination  passanger weather  temperature  time coupon  \
# 156    No Urgent Place  Friend(s)   Sunny           80  10AM    Bar
# 167               Home      Alone   Sunny           55   6PM    Bar
# 171               Work      Alone   Sunny           55   7AM    Bar
# 454    No Urgent Place  Friend(s)   Sunny           80  10AM    Bar
# 465               Home      Alone   Sunny           55   6PM    Bar
# ...                ...        ...     ...          ...   ...    ...
# 12198  No Urgent Place  Friend(s)   Sunny           80  10PM    Bar
# 12199  No Urgent Place  Friend(s)   Sunny           55  10PM    Bar
# 12202  No Urgent Place      Alone   Rainy           55  10AM    Bar
# 12207             Home    Partner   Sunny           30  10PM    Bar
# 12215             Work      Alone   Snowy           30   7AM    Bar
#
#       expiration  gender age      maritalStatus  ...  CoffeeHouse CarryAway  \
# ...

# %%
bar_3_or_fewer
# Out:
#            destination  passanger weather  temperature  time coupon  \
# 9      No Urgent Place     Kid(s)   Sunny           80  10AM    Bar
# 13                Home      Alone   Sunny           55   6PM    Bar
# 17                Work      Alone   Sunny           55   7AM    Bar
# 24     No Urgent Place  Friend(s)   Sunny           80  10AM    Bar
# 35                Home      Alone   Sunny           55   6PM    Bar
# ...                ...        ...     ...          ...   ...    ...
# 12663  No Urgent Place  Friend(s)   Sunny           80  10PM    Bar
# 12664  No Urgent Place  Friend(s)   Sunny           55  10PM    Bar
# 12667  No Urgent Place      Alone   Rainy           55  10AM    Bar
# 12670  No Urgent Place    Partner   Rainy           55   6PM    Bar
# 12682             Work      Alone   Snowy           30   7AM    Bar
#
#       expiration  gender age      maritalStatus  ...  CoffeeHouse CarryAway  \
# ...

# %% [markdown]
# # Answer to question 3

# %%
# Count the occurrences of each value in the column
bv1 = bar_3_or_more["Y"].value_counts()

# Calculate the ratio
br1 = bv1[1] / len(bar_3_or_more["Y"])
print(br1)

# Count the occurrences of each value in the column
bv2 = bar_3_or_fewer["Y"].value_counts()

# Calculate the ratio
br2 = bv2[1] / len(bar_3_or_fewer["Y"])
print(br2)

# people who go to the bar more than once are much more likely to use the coupon
# Out:
# 0.7688442211055276
# 0.37073707370737075

# %% [markdown]
# 4. Compare the acceptance rate between drivers who go to a bar more than once a month and are over the age of 25 to the all others.  Is there a difference?

# %%
bar_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2017 entries, 9 to 12682
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           2017 non-null   object
#  1   passanger             2017 non-null   object
#  2   weather               2017 non-null   object
#  3   temperature           2017 non-null   int64
#  4   time                  2017 non-null   object
#  5   coupon                2017 non-null   object
#  6   expiration            2017 non-null   object
#  7   gender                2017 non-null   object
#  8   age                   2017 non-null   object
#  9   maritalStatus         2017 non-null   object
#  10  has_children          2017 non-null   int64
#  11  education             2017 non-null   object
#  12  occupation            2017 non-null   object
#  13  income                2017 non-null   object
#  14  car                   13 non-null     object
# ...

# %%
bar_data["Bar"].unique()
# Out:
# array(['never', 'less1', '1~3', 'gt8', nan, '4~8'], dtype=object)

# %%
bar_nan_counts = bar_data.isna().sum()
bar_nan_counts
# Out:
# destination                0
# passanger                  0
# weather                    0
# temperature                0
# time                       0
# coupon                     0
# expiration                 0
# gender                     0
# age                        0
# maritalStatus              0
# has_children               0
# education                  0
# occupation                 0
# income                     0
# car                     2004
# Bar                       21
# CoffeeHouse               39
# CarryAway                 24
# RestaurantLessThan20      23
# Restaurant20To50          36
# toCoupon_GEQ5min           0
# toCoupon_GEQ15min          0
# toCoupon_GEQ25min          0
# direction_same             0
# direction_opp              0
# Y                          0
# dtype: int64

# %%
# Convert a column to int
bar_data["age"].unique()
ages = ['21', '46', '26', '31', '41', '50plus', '36', 'below21']
# Use .query() to filter for values not in a list
'''
over_25 = bar_data.query("age not in ['21', 'below21']")
over_25
over_1_visit = bar_data.query("(Bar != 'less1' and Bar != 'never')")
over_1_visit["Bar"].unique()
'''
customers_over_25_and_over_1_visit = bar_data.query("(Bar != 'less1' and Bar != 'never') & age not in ['21', 'below21']")
customers_not_over_25_and_not_over_1_visit = bar_data.query("(Bar == 'less1' or Bar == 'never') & age in ['21', 'below21']")
#bar_data["age"] = bar_data["age"].astype(int)
#bar_data.query("(Bar != 'less1' and Bar != 'never') & (age > 25)")

# %%
customers_over_25_and_over_1_visit
# Out:
#            destination  passanger weather  temperature  time coupon  \
# 112    No Urgent Place  Friend(s)   Sunny           80  10AM    Bar
# 123               Home      Alone   Sunny           55   6PM    Bar
# 127               Work      Alone   Sunny           55   7AM    Bar
# 156    No Urgent Place  Friend(s)   Sunny           80  10AM    Bar
# 167               Home      Alone   Sunny           55   6PM    Bar
# ...                ...        ...     ...          ...   ...    ...
# 12481  No Urgent Place  Friend(s)   Sunny           80  10PM    Bar
# 12482  No Urgent Place  Friend(s)   Sunny           55  10PM    Bar
# 12485  No Urgent Place      Alone   Rainy           55  10AM    Bar
# 12488  No Urgent Place    Partner   Rainy           55   6PM    Bar
# 12500             Work      Alone   Snowy           30   7AM    Bar
#
#       expiration  gender age      maritalStatus  ...  CoffeeHouse CarryAway  \
# ...

# %%
customers_not_over_25_and_not_over_1_visit
# Out:
#            destination  passanger weather  temperature  time coupon  \
# 9      No Urgent Place     Kid(s)   Sunny           80  10AM    Bar
# 13                Home      Alone   Sunny           55   6PM    Bar
# 17                Work      Alone   Sunny           55   7AM    Bar
# 24     No Urgent Place  Friend(s)   Sunny           80  10AM    Bar
# 35                Home      Alone   Sunny           55   6PM    Bar
# ...                ...        ...     ...          ...   ...    ...
# 12613  No Urgent Place  Friend(s)   Sunny           80  10PM    Bar
# 12614  No Urgent Place  Friend(s)   Sunny           55  10PM    Bar
# 12617  No Urgent Place      Alone   Rainy           55  10AM    Bar
# 12620  No Urgent Place    Partner   Rainy           55   6PM    Bar
# 12632             Work      Alone   Snowy           30   7AM    Bar
#
#       expiration  gender age      maritalStatus  ...  CoffeeHouse CarryAway  \
# ...

# %% [markdown]
# # Answer to question 4

# %%
# Count the occurrences of each value in the column
value_counts2 = customers_over_25_and_over_1_visit["Y"].value_counts()

# Calculate the ratio
ratio2 = value_counts2[1] / len(customers_over_25_and_over_1_visit["Y"])
print(ratio2)

# Count the occurrences of each value in the column
value_counts3 = customers_not_over_25_and_not_over_1_visit["Y"].value_counts()

# Calculate the ratio
ratio3 = value_counts3[1] / len(customers_not_over_25_and_not_over_1_visit["Y"])
print(ratio3)

'''there is a pretty big gap between customers who accept the bar coupon that are over 25 and have over 1 visit vs those who 
do not'''
# Out:
# 0.6818181818181818
# 0.3944954128440367

# %% [markdown]
# 5. Use the same process to compare the acceptance rate between drivers who go to bars more than once a month and had passengers that were not a kid and had occupations other than farming, fishing, or forestry.

# %% [markdown]
# # Answer to question 5

# %%
#df3 = bar_data.query("(Bar != 'less1' and Bar != 'never') & (passenger != 'Kid(s)') & ")
df3 = bar_data.query("(Bar != 'less1' and Bar != 'never') & (passanger != 'Kid(s)') & (occupation != 'Farming Fishing & Forestry')")
df4 = bar_data.query("(Bar == 'less1' or Bar == 'never') & (passanger == 'Kid(s)') & (occupation == 'Farming Fishing & Forestry')")
#bar_data["occupation"].unique()
#df3["passanger"].unique()
# Count the occurrences of each value in the column
value_counts4 = df3["Y"].value_counts()

# Calculate the ratio
ratio4 = value_counts4[1] / len(df3["Y"])

# Count the occurrences of each value in the column
value_counts5 = df4["Y"].value_counts()

# Calculate the ratio
ratio5 = value_counts5[1] / len(df4["Y"])
print(ratio4)
print(ratio5)

''' the customers without kids, who have visited more than once, and are not farmers, fishers, or foresters have a much higher 
chance of using the coupon compared to customers who don't have those features '''
# Out:
# 0.70298769771529
# 0.3333333333333333

# %%
c1 = bar_data.query("(Bar != 'less1' and Bar != 'never')")
c2 = bar_data.query("(passanger != 'Kid(s)')")
c3 = bar_data.query("(occupation != 'Farming Fishing & Forestry')")

# START C1 RATIO 
# Count the occurrences of each value in the column
vc_c1 = c1["Y"].value_counts()

# Calculate the ratio
rc1 = vc_c1[1] / len(c1["Y"])
# END C1 RATIO

# START C2 RATIO 
# Count the occurrences of each value in the column
vc_c2 = c2["Y"].value_counts()

# Calculate the ratio
rc2 = vc_c2[1] / len(c2["Y"])
# END C2 RATIO 

# START C3 RATIO 
# Count the occurrences of each value in the column
vc_c3 = c3["Y"].value_counts()

# Calculate the ratio
rc3 = vc_c3[1] / len(c3["Y"])
# END C3 RATIO 
print(rc1)
print(rc2)
print(rc3)

# Shows that people who go to bars more than once a month are much more likely to use the coupon compared to others
# Out:
# 0.6774716369529984
# 0.43290999447818884
# 0.4098605577689243

# %% [markdown]
# 6. Compare the acceptance rates between those drivers who:
#
# - go to bars more than once a month, had passengers that were not a kid, and were not widowed *OR*
# - go to bars more than once a month and are under the age of 30 *OR*
# - go to cheap restaurants more than 4 times a month and income is less than 50K.

# %%
ages2 = ['21', '46', '26', '31', '41', '50plus', '36', 'below21']

c4 = bar_data.query("(Bar != 'less1' and Bar != 'never')")
c5 = bar_data.query("age in ['21', 'below21', '26']")

# START C4 RATIO 
# Count the occurrences of each value in the column
vc_c4 = c4["Y"].value_counts()

# Calculate the ratio
rc4 = vc_c4[1] / len(c4["Y"])

# START C5 RATIO 
# Count the occurrences of each value in the column
vc_c5 = c5["Y"].value_counts()

# Calculate the ratio
rc5 = vc_c5[1] / len(c5["Y"])

print(rc4)
print(rc5)
# Out:
# 0.6774716369529984
# 0.489432703003337

# %% [markdown]
# 7.  Based on these observations, what do you hypothesize about drivers who accepted the bar coupons?

# %% [markdown]
# Based on all of these observations, I can conclude that the prime factor in a customer deciding whether or not they would use the coupon right away or before it expires

# %% [markdown]
# ### Independent Investigation
#
# Using the bar coupon example as motivation, you are to explore one of the other coupon groups and try to determine the characteristics of passengers who accept the coupons.

# %% [markdown]
# # Examining the Restauraunt (20-50) range

# %%
expensive_restaurants = data.query("coupon == 'Restaurant(20-50)'")
expensive_restaurants
# Out:
#            destination passanger weather  temperature  time  \
# 14                Home     Alone   Sunny           55   6PM
# 18                Work     Alone   Sunny           80   7AM
# 36                Home     Alone   Sunny           55   6PM
# 40                Work     Alone   Sunny           80   7AM
# 58                Home     Alone   Sunny           55   6PM
# ...                ...       ...     ...          ...   ...
# 12657             Home     Alone   Sunny           80   6PM
# 12661             Work     Alone   Sunny           80   7AM
# 12669  No Urgent Place   Partner   Sunny           30  10AM
# 12676             Home     Alone   Sunny           80   6PM
# 12683             Work     Alone   Sunny           80   7AM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 14     Restaurant(20-50)         1d  Female  21  Unmarried partner  ...
# 18     Restaurant(20-50)         1d  Female  21  Unmarried partner  ...
# ...

# %%
sns.displot(data = expensive_restaurants, x = "maritalStatus")
plt.xticks(rotation = 45)

# from this, we can see that married couples and single make up the most of the maritalStatus column, 
# so I will use these 2 to compare accepted and rejected coupons
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Unmarried partner'),
#   Text(1, 0, 'Single'),
#   Text(2, 0, 'Married partner'),
#   Text(3, 0, 'Divorced'),
#   Text(4, 0, 'Widowed')])

# %%
expensive_restaurants["maritalStatus"].unique()
# Out:
# array(['Unmarried partner', 'Single', 'Married partner', 'Divorced',
#        'Widowed'], dtype=object)

# %%
er_married = expensive_restaurants.query("maritalStatus == 'Married partner'")
er_married
# Out:
#            destination passanger weather  temperature  time  \
# 80                Home     Alone   Sunny           55   6PM
# 84                Work     Alone   Sunny           80   7AM
# 146               Home     Alone   Sunny           55   6PM
# 150               Work     Alone   Sunny           80   7AM
# 273               Home     Alone   Sunny           55   6PM
# ...                ...       ...     ...          ...   ...
# 12640  No Urgent Place    Kid(s)   Sunny           30  10PM
# 12650             Home    Kid(s)   Sunny           55  10PM
# 12651             Home    Kid(s)   Sunny           55  10PM
# 12657             Home     Alone   Sunny           80   6PM
# 12661             Work     Alone   Sunny           80   7AM
#
#                   coupon expiration  gender age    maritalStatus  ...  \
# 80     Restaurant(20-50)         1d    Male  46  Married partner  ...
# 84     Restaurant(20-50)         1d    Male  46  Married partner  ...
# ...

# %%
# Count the occurrences of each value in the column
er_m = er_married["Y"].value_counts()

# Calculate the ratio
er_ratio = er_m[1] / len(er_married["Y"])
er_ratio

# expensive restaurants with customers that are married are not likely to use the coupon on them
# Out:
# 0.41788617886178864

# %%
er_single = expensive_restaurants.query("maritalStatus == 'Single'")
er_single
# Out:
#            destination passanger weather  temperature  time  \
# 36                Home     Alone   Sunny           55   6PM
# 40                Work     Alone   Sunny           80   7AM
# 58                Home     Alone   Sunny           55   6PM
# 62                Work     Alone   Sunny           80   7AM
# 102               Home     Alone   Sunny           55   6PM
# ...                ...       ...     ...          ...   ...
# 12583             Home     Alone   Sunny           80  10PM
# 12589             Work     Alone   Sunny           80   7AM
# 12669  No Urgent Place   Partner   Sunny           30  10AM
# 12676             Home     Alone   Sunny           80   6PM
# 12683             Work     Alone   Sunny           80   7AM
#
#                   coupon expiration gender age maritalStatus  ...  \
# 36     Restaurant(20-50)         1d   Male  21        Single  ...
# 40     Restaurant(20-50)         1d   Male  21        Single  ...
# ...

# %%
# Count the occurrences of each value in the column
er_s = er_single["Y"].value_counts()

# Calculate the ratio
ers_ratio = er_s[1] / len(er_single["Y"])
ers_ratio

# similar story here compared to married couples in this same category, they are not likely to use the coupon
# Out:
# 0.46221441124780316

# %%
remaining_status = expensive_restaurants.query("maritalStatus != 'Single' and maritalStatus != 'Married partner'")
remaining_status
# Out:
#            destination passanger weather  temperature  time  \
# 14                Home     Alone   Sunny           55   6PM
# 18                Work     Alone   Sunny           80   7AM
# 124               Home     Alone   Sunny           55   6PM
# 128               Work     Alone   Sunny           80   7AM
# 223    No Urgent Place   Partner   Sunny           80  10AM
# ...                ...       ...     ...          ...   ...
# 12605             Home     Alone   Sunny           80  10PM
# 12611             Work     Alone   Sunny           80   7AM
# 12619  No Urgent Place   Partner   Sunny           30  10AM
# 12626             Home     Alone   Sunny           80   6PM
# 12633             Work     Alone   Sunny           80   7AM
#
#                   coupon expiration  gender     age      maritalStatus  ...  \
# 14     Restaurant(20-50)         1d  Female      21  Unmarried partner  ...
# 18     Restaurant(20-50)         1d  Female      21  Unmarried partner  ...
# ...

# %%
# Count the occurrences of each value in the column
er_rem = remaining_status["Y"].value_counts()

# Calculate the ratio
erem_ratio = er_rem[1] / len(remaining_status["Y"])
erem_ratio

# all groups that I've made here seem to have lower than 50% chances of using the coupon on expensive restaurants
# Out:
# 0.44805194805194803

# %% [markdown]
# Based on these ratios, I can conclude that people of all marital status groups for expansive restaurants aren't likely to use the coupon before it expires
# The ratios for all 3 groups of marital status customers that I used (married, single, remaining) were all between 40 and 47%

# %% [markdown]
# # Examining the Restaurant (<20) group

# %%
data["coupon"].unique()
# Out:
# array(['Restaurant(<20)', 'Coffee House', 'Carry out & Take away', 'Bar',
#        'Restaurant(20-50)'], dtype=object)

# %%
restaurant_less_20 = data.query("coupon == 'Restaurant(<20)'")
restaurant_less_20
# Out:
#            destination  passanger weather  temperature  time           coupon  \
# 0      No Urgent Place      Alone   Sunny           55   2PM  Restaurant(<20)
# 5      No Urgent Place  Friend(s)   Sunny           80   6PM  Restaurant(<20)
# 7      No Urgent Place     Kid(s)   Sunny           80  10AM  Restaurant(<20)
# 10     No Urgent Place     Kid(s)   Sunny           80   2PM  Restaurant(<20)
# 11     No Urgent Place     Kid(s)   Sunny           55   2PM  Restaurant(<20)
# ...                ...        ...     ...          ...   ...              ...
# 12666  No Urgent Place  Friend(s)   Snowy           30   2PM  Restaurant(<20)
# 12668  No Urgent Place      Alone   Sunny           80  10AM  Restaurant(<20)
# 12671  No Urgent Place    Partner   Snowy           30  10AM  Restaurant(<20)
# 12677             Home    Partner   Sunny           30   6PM  Restaurant(<20)
# 12678             Home    Partner   Sunny           30  10PM  Restaurant(<20)
#
# ...

# %%
# Count the occurrences of each value in the column
r_less_20_count_accepted = restaurant_less_20["Y"].value_counts()

# Calculate the ratio
rlca_ratio = r_less_20_count_accepted[1] / len(restaurant_less_20["Y"])
rlca_ratio
# Out:
# 0.7071069633883704

# %% [markdown]
# From this we can see that a high percentage of people accept the coupon for cheap restaurants

# %%
restaurant_less_20["has_children"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
r_less_20_with_children = restaurant_less_20.query("has_children == 1")
r_less_20_with_children
# Out:
#            destination  passanger weather  temperature  time           coupon  \
# 0      No Urgent Place      Alone   Sunny           55   2PM  Restaurant(<20)
# 5      No Urgent Place  Friend(s)   Sunny           80   6PM  Restaurant(<20)
# 7      No Urgent Place     Kid(s)   Sunny           80  10AM  Restaurant(<20)
# 10     No Urgent Place     Kid(s)   Sunny           80   2PM  Restaurant(<20)
# 11     No Urgent Place     Kid(s)   Sunny           55   2PM  Restaurant(<20)
# ...                ...        ...     ...          ...   ...              ...
# 12636  No Urgent Place     Kid(s)   Sunny           55   6PM  Restaurant(<20)
# 12642  No Urgent Place  Friend(s)   Sunny           80   6PM  Restaurant(<20)
# 12646  No Urgent Place  Friend(s)   Snowy           30   2PM  Restaurant(<20)
# 12648  No Urgent Place      Alone   Sunny           80  10AM  Restaurant(<20)
# 12649  No Urgent Place     Kid(s)   Sunny           55   6PM  Restaurant(<20)
#
# ...

# %%
# Count the occurrences of each value in the column
r_less_20_with_children_count_accepted = r_less_20_with_children["Y"].value_counts()

# Calculate the ratio
rlcac_ratio = r_less_20_with_children_count_accepted[1] / len(r_less_20_with_children["Y"])
rlcac_ratio
# Out:
# 0.6965217391304348

# %%
r_less_20_male = restaurant_less_20.query("gender == 'Male'")
r_less_20_male
# Out:
#            destination  passanger weather  temperature  time           coupon  \
# 22     No Urgent Place      Alone   Sunny           55   2PM  Restaurant(<20)
# 29     No Urgent Place  Friend(s)   Sunny           80   2PM  Restaurant(<20)
# 31     No Urgent Place  Friend(s)   Sunny           80   6PM  Restaurant(<20)
# 42                Work      Alone   Sunny           55   7AM  Restaurant(<20)
# 44     No Urgent Place      Alone   Sunny           55   2PM  Restaurant(<20)
# ...                ...        ...     ...          ...   ...              ...
# 12666  No Urgent Place  Friend(s)   Snowy           30   2PM  Restaurant(<20)
# 12668  No Urgent Place      Alone   Sunny           80  10AM  Restaurant(<20)
# 12671  No Urgent Place    Partner   Snowy           30  10AM  Restaurant(<20)
# 12677             Home    Partner   Sunny           30   6PM  Restaurant(<20)
# 12678             Home    Partner   Sunny           30  10PM  Restaurant(<20)
#
# ...

# %%
# Count the occurrences of each value in the column
rlm = r_less_20_male["Y"].value_counts()

# Calculate the ratio
rlm_ratio = rlm[1] / len(r_less_20_male["Y"])
rlm_ratio
# Out:
# 0.717948717948718

# %%
r_less_20_female = restaurant_less_20.query("gender == 'Female'")
r_less_20_female
# Out:
#            destination  passanger weather  temperature  time           coupon  \
# 0      No Urgent Place      Alone   Sunny           55   2PM  Restaurant(<20)
# 5      No Urgent Place  Friend(s)   Sunny           80   6PM  Restaurant(<20)
# 7      No Urgent Place     Kid(s)   Sunny           80  10AM  Restaurant(<20)
# 10     No Urgent Place     Kid(s)   Sunny           80   2PM  Restaurant(<20)
# 11     No Urgent Place     Kid(s)   Sunny           55   2PM  Restaurant(<20)
# ...                ...        ...     ...          ...   ...              ...
# 12618  No Urgent Place      Alone   Sunny           80  10AM  Restaurant(<20)
# 12621  No Urgent Place    Partner   Snowy           30  10AM  Restaurant(<20)
# 12627             Home    Partner   Sunny           30   6PM  Restaurant(<20)
# 12628             Home    Partner   Sunny           30  10PM  Restaurant(<20)
# 12636  No Urgent Place     Kid(s)   Sunny           55   6PM  Restaurant(<20)
#
# ...

# %%
# Count the occurrences of each value in the column
rlf = r_less_20_female["Y"].value_counts()

# Calculate the ratio
rlf_ratio = rlf[1] / len(r_less_20_female["Y"])
rlf_ratio
# Out:
# 0.6966924700914848

# %%
#ages2 = ['21', '46', '26', '31', '41', '50plus', '36', 'below21']
# checking marital status of divorced customers with resaurants < 20 
div_res_less_20 = restaurant_less_20.query("maritalStatus == 'Unmarried partner' & age in ['below21', '21', '26', '31']")
div_res_less_20
# Out:
#            destination  passanger weather  temperature  time           coupon  \
# 0      No Urgent Place      Alone   Sunny           55   2PM  Restaurant(<20)
# 5      No Urgent Place  Friend(s)   Sunny           80   6PM  Restaurant(<20)
# 7      No Urgent Place     Kid(s)   Sunny           80  10AM  Restaurant(<20)
# 10     No Urgent Place     Kid(s)   Sunny           80   2PM  Restaurant(<20)
# 11     No Urgent Place     Kid(s)   Sunny           55   2PM  Restaurant(<20)
# ...                ...        ...     ...          ...   ...              ...
# 12616  No Urgent Place  Friend(s)   Snowy           30   2PM  Restaurant(<20)
# 12618  No Urgent Place      Alone   Sunny           80  10AM  Restaurant(<20)
# 12621  No Urgent Place    Partner   Snowy           30  10AM  Restaurant(<20)
# 12627             Home    Partner   Sunny           30   6PM  Restaurant(<20)
# 12628             Home    Partner   Sunny           30  10PM  Restaurant(<20)
#
# ...

# %%
# Count the occurrences of each value in the column
t1 = div_res_less_20["Y"].value_counts()

# Calculate the ratio
c_ratio = t1[1] / len(div_res_less_20["Y"])
c_ratio
# Out:
# 0.7418478260869565

# %% [markdown]
# # Findings:
# Gender doesn't seem to have much of an impact on customers who use their coupons soon on cheap restaurants, and both have
# around a 70% accept rate on the coupons.
#
# Customers that are less than 40 years old and have partners (but not married) are the most likely people in this group to use the coupon once they recieve it.

# %% [markdown]
# # Examing the Carry Out Group

# %%
carry = data.query("coupon == 'Carry out & Take away'")
carry["time"].unique()
# Out:
# array(['10AM', '2PM', '7AM', '10PM', '6PM'], dtype=object)

# %%
# Count the occurrences of each value in the column
c = carry["Y"].value_counts()

# Calculate the ratio
c_ratio = c[1] / len(carry["Y"])
c_ratio
# Out:
# 0.7354784788967823

# %%
fc = carry.query("time == '2PM' & passanger == 'Friend(s)'")
fc
# Out:
#           destination  passanger weather  temperature time  \
# 6     No Urgent Place  Friend(s)   Sunny           55  2PM
# 33    No Urgent Place  Friend(s)   Sunny           55  2PM
# 55    No Urgent Place  Friend(s)   Sunny           55  2PM
# 72    No Urgent Place  Friend(s)   Sunny           55  2PM
# 99    No Urgent Place  Friend(s)   Sunny           55  2PM
# ...               ...        ...     ...          ...  ...
# 3899  No Urgent Place  Friend(s)   Sunny           55  2PM
# 3921  No Urgent Place  Friend(s)   Sunny           55  2PM
# 3938  No Urgent Place  Friend(s)   Sunny           55  2PM
# 3965  No Urgent Place  Friend(s)   Sunny           55  2PM
# 3987  No Urgent Place  Friend(s)   Sunny           55  2PM
#
#                      coupon expiration  gender     age      maritalStatus  \
# 6     Carry out & Take away         1d  Female      21  Unmarried partner
# 33    Carry out & Take away         1d    Male      21             Single
# ...

# %%
# Count the occurrences of each value in the column
c2 = fc["Y"].value_counts()

# Calculate the ratio
c2_ratio = c2[1] / len(fc["Y"])
c2_ratio
# Out:
# 0.8895027624309392

# %%
time_percentages = {"time":['10AM', '2PM', '7AM', '10PM', '6PM'], "ratio":[0.70, 0.86, 0.65, 0.75, 0.82]}
sns.barplot(data = time_percentages, x = "time", y = "ratio")
# ['10AM', '2PM', '7AM', '10PM', '6PM']
# 10am = 70%
# 2pm = 86% 
# 6pm 82% 
# 7am = 65% 
# 10pm = 75% 
#p = [65, 70, 86, 82, 75] 

# Set labels and title
plt.xlabel('Time')
plt.ylabel('Value (out of 1.0)')
plt.title('Likelihood of customer using carry out coupon')
# Out:
# Text(0.5, 1.0, 'Likelihood of customer using carry out coupon')

# %% [markdown]
# # Findings
# People who were sent the coupon from 2pm - 6pm have the highest chances of using a coupon at a carry out and take away location

# %%
sns.displot(data = carry, x = "time", hue = "Y")
plt.title("Carry out time comparison")
# 1 = accepted, 0 = not accepted
# Out:
# Text(0.5, 1.0, 'Carry out time comparison')

# %% [markdown]
# # Findings
# Based on making a histogram with the hue indicating whether or not the coupon was accepted or not, we can see that the ratio for people around the afternoon to late night (2pm - 10pm) are much more likely to use the coupon as opposed to the early morning where many more people seem to ignore the coupon.

# %% [markdown]
# # Examining Coffee group

# %%
coffee = data.query("coupon == 'Coffee House'")
coffee
# Out:
#            destination  passanger weather  temperature  time        coupon  \
# 1      No Urgent Place  Friend(s)   Sunny           80  10AM  Coffee House
# 3      No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 4      No Urgent Place  Friend(s)   Sunny           80   2PM  Coffee House
# 12     No Urgent Place     Kid(s)   Sunny           55   6PM  Coffee House
# 15                Home      Alone   Sunny           80   6PM  Coffee House
# ...                ...        ...     ...          ...   ...           ...
# 12656             Home      Alone   Snowy           30  10PM  Coffee House
# 12659             Work      Alone   Snowy           30   7AM  Coffee House
# 12674             Home      Alone   Rainy           55  10PM  Coffee House
# 12675             Home      Alone   Snowy           30  10PM  Coffee House
# 12681             Work      Alone   Snowy           30   7AM  Coffee House
#
# ...

# %%
sns.displot(data = coffee, x = "CoffeeHouse")
plt.title("Frequency of visit groups in CoffeeHouse")
# Out:
# Text(0.5, 1.0, 'Frequency of visit groups in CoffeeHouse')

# %%
freq_coffee_visits = coffee.query("CoffeeHouse in ['1~3', 'gt8', '4~8'] & time == '10AM'")
freq_coffee_visits
# Out:
#            destination  passanger weather  temperature  time        coupon  \
# 45     No Urgent Place  Friend(s)   Sunny           80  10AM  Coffee House
# 56     No Urgent Place      Alone   Sunny           55  10AM  Coffee House
# 67     No Urgent Place  Friend(s)   Sunny           80  10AM  Coffee House
# 111    No Urgent Place  Friend(s)   Sunny           80  10AM  Coffee House
# 122    No Urgent Place      Alone   Sunny           55  10AM  Coffee House
# ...                ...        ...     ...          ...   ...           ...
# 10687  No Urgent Place      Alone   Rainy           55  10AM  Coffee House
# 10740  No Urgent Place      Alone   Sunny           80  10AM  Coffee House
# 10743  No Urgent Place      Alone   Rainy           55  10AM  Coffee House
# 10754  No Urgent Place      Alone   Sunny           80  10AM  Coffee House
# 10757  No Urgent Place      Alone   Rainy           55  10AM  Coffee House
#
# ...

# %%
# Count the occurrences of each value in the column
cf = freq_coffee_visits["Y"].value_counts()

# Calculate the ratio
cf_ratio = cf[1] / len(freq_coffee_visits["Y"])
cf_ratio
# Out:
# 0.8129496402877698

# %%
# the chances that someone will get a coffee if they have visited the coffee place more than once and it is 10AM is very likely
# most people after the morning are not likely to use the coupon on coffee, which makes sense 
# and obviously at night time people are very unlikely to even get coffee in the first place so this justifies how low 6/10pm are

# %%
sns.displot(data = coffee, x = "time", hue = 'Y')
plt.title("Time comparison for customers in coffee group")
# Out:
# Text(0.5, 1.0, 'Time comparison for customers in coffee group')
